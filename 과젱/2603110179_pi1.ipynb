# %%
import math
print("1번 결과:", math.pi)
# Out:
# 1번 결과: 3.141592653589793

# %%
import math as m
print("2번 결과:", m.pi)
# Out:
# 2번 결과: 3.141592653589793

# %%
from math import pi
print("3번 결과:", pi)
# Out:
# 3번 결과: 3.141592653589793

# %%
from math import pi as p
print("4번 결과:", p)
# Out:
# 4번 결과: 3.141592653589793
